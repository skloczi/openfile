# %%
from obspy import read
import matplotlib.pyplot as plt

# %%
st = read("/Users/annamaria/PhD/work/Testing/open_files/Data/mSEED/2016-11-13-mww78-south-island-new-zealand-6.miniseed")
print(st[0].stats)
# Out:
#          network: IU
#          station: RAO
#         location: 00
#          channel: BH1
#        starttime: 2016-11-13T11:05:33.019538Z
#          endtime: 2016-11-13T11:26:32.994538Z
#    sampling_rate: 40.0
#            delta: 0.025
#             npts: 50400
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'dataquality': 'M', 'number_of_records': 330, 'encoding': 'STEIM2', 'byteorder': '>', 'record_length': 512, 'filesize': 954880})

# %%
# defining the data vector of the recording defined in []
data_vec = st[0].data
print(data_vec)
plt.plot(data_vec)
# Out:
# [    4331     1931     -745 ..., -1410039 -1413984 -1419787]
