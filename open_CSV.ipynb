# %%
import csv

# %%
# Exctracting file info
with open("/Users/annamaria/PhD/work/Testing/open_files/Data/CSV/IU.RAO.00.BH1.M.2016-11-13T110533.019538.csv") as csv_file:
    file = csv.reader(csv_file, delimiter=' ')
    for row in file:
        if row[0] == '#': 
            print(' '.join(row[1:]))
# Out:
# dataset: GeoCSV 2.0
# delimiter: ,
# SID: IU_RAO_00_BH1
# sample_count: 74400
# sample_rate_hz: 40
# start_time: 2016-11-13T11:05:33.019538Z
# field_unit: Counts
# field_type: INTEGER

# %%
# Exctracting data
data = []
with open("/Users/annamaria/PhD/work/Testing/Data/CSV/IU.RAO.00.BH1.M.2016-11-13T110533.019538.csv") as csv_file:
    file = csv.reader(csv_file, delimiter=' ')
    for row in file:
        if row[0] == '#' or row[0] == 'Sample':
            continue
        else:
            data.append(float(row[0]))
plt.plot(data)
